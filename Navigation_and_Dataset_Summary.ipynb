# %% [markdown]
# # Power System Data Collection and Validation
# This project aims to gather, clean, and validate time series datasets related to power and energy systems. The data will be centralized, documented, and used to support planning and simulation tasks within energy network research.
#
# ---

# %% [markdown]
# #### Instructions
#
# 1. **Run the Code Cells Below**
#
# 2. **Explore Further**
#    Detailed Jupyter Notebook is available in each source's subfolder.

# %% [markdown]
# #### How to Query the Dataset
#
# You can use the `query_data_sources()` function to filter datasets based on specific criteria such as:
#
# - Type of load (e.g., active, reactive)
# - Type of renewable source (e.g., solar, wind)
# - Whether the dataset is synthetic or real
# - Presence of price/economic data
# - Time resolution or geographical coverage
#
# #### Example Queries:
#
# - Find datasets with both solar and wind data
# - Find datasets that are synthetic only
# - Find datasets that include price data and wind generation
# - Filter by specific load types like residential or industrial
#
# Use the function in code cells like this:

# %%
from IPython.display import display
from utils.data_catalog import load_data_sources, query_data_sources, show_folder_links

# Load the dataset catalog
df = load_data_sources()
display(df)
# Out:
#                               Source  \
# 0      AgenceORE_Consumption_lt36kVA
# 1  eCO2mix_France_GenerationBySource
# 2                               OPSD
# 3                           SimBench
#
#                                                                                                                                              Description  \
# 0                                      Aggregated half-hourly electricity consumption data from consumption points with power subscriptions below 36kVA.
# 1  Real-time and historical electricity generation, consumption, forecast, and emissions data for France, disaggregated by energy source and technology.
# 2                                                                                              Open Power System Data - EU-wide TSO-provided time series
# 3                                                                                             Synthetic power system benchmark datasets for grid studies
#
#   Number of Profiles                                         Profile Types  \
# 0                130        [load, consumption points, energy consumption]
# 1                 36  [load, production, renewable, forecast, environment]
# 2                220          [load, renewable, capacity, price, forecast]
# 3                614                [load, renewable, powerplant, storage]
#
#                                                     Load  \
# 0                      [active, aggregated, residential]
# 1            [consumption, active, national, aggregated]
# 2             [active, aggregated, national, historical]
# 3  [active, reactive, residential, industry, commercial]
#
#                          Renewable      Environment  Economy  Processed  \
# 0                               []               []       []       True
# 1  [solar, wind, hydro, bioenergy]  [co2 intensity]       []       True
# 2                    [solar, wind]               []  [price]       True
# 3    [solar, wind, biomass, hydro]               []       []       True
#
#    Synthetic    Horizon        Time Resolution  \
# 0      False  2020–2024                in]
# 1      False  2012-2022                in]
# 2      False  2015-2020  in, 30min, 60min]
# 3       True  2016-2017                in]
#
#                                                              Geographical  \
# 0                                                                [France]
# 1                                                                [France]
# 2  [EU, United Kingdom, Switzerland, Norway, Montenegro, Serbia, Ukraine]
# 3                                                               [Germany]
#
#                                Folder
# 0      AgenceORE_Consumption_lt36kVA/
# 1  eCO2mix_France_GenerationBySource/
# 2                    OPSD_TimeSeries/
# 3                           SimBench/

# %%
# Filter datasets by criteria (e.g., solar + wind)
results = query_data_sources(df, renewable=["solar", "wind"])
display(results)
# Out:
#                               Source  \
# 0  eCO2mix_France_GenerationBySource
# 1                               OPSD
# 2                           SimBench
#
#                                                                                                                                              Description  \
# 0  Real-time and historical electricity generation, consumption, forecast, and emissions data for France, disaggregated by energy source and technology.
# 1                                                                                              Open Power System Data - EU-wide TSO-provided time series
# 2                                                                                             Synthetic power system benchmark datasets for grid studies
#
#   Number of Profiles                                         Profile Types  \
# 0                 36  [load, production, renewable, forecast, environment]
# 1                220          [load, renewable, capacity, price, forecast]
# 2                614                [load, renewable, powerplant, storage]
#
#                                                     Load  \
# 0            [consumption, active, national, aggregated]
# 1             [active, aggregated, national, historical]
# 2  [active, reactive, residential, industry, commercial]
#
#                          Renewable      Environment  Economy  Processed  \
# 0  [solar, wind, hydro, bioenergy]  [co2 intensity]       []       True
# 1                    [solar, wind]               []  [price]       True
# 2    [solar, wind, biomass, hydro]               []       []       True
#
#    Synthetic    Horizon        Time Resolution  \
# 0      False  2012-2022                in]
# 1      False  2015-2020  in, 30min, 60min]
# 2       True  2016-2017                in]
#
#                                                              Geographical  \
# 0                                                                [France]
# 1  [EU, United Kingdom, Switzerland, Norway, Montenegro, Serbia, Ukraine]
# 2                                                               [Germany]
#
#                                Folder
# 0  eCO2mix_France_GenerationBySource/
# 1                    OPSD_TimeSeries/
# 2                           SimBench/

# %%
# Show folder links for matching datasets
show_folder_links(results)
# Out:
# - [eCO2mix_France_GenerationBySource](eCO2mix_France_GenerationBySource/)
# - [OPSD](OPSD_TimeSeries/)
# - [SimBench](SimBench/)
